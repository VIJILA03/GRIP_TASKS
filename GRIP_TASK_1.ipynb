# %%
#importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_set="http://bit.ly/w-data"
data=pd.read_csv(data_set)
x=data.iloc[: ,:1].values
y=data.iloc[: ,-1].values

# %%
data.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   25 non-null     float64
#  1   Scores  25 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 528.0 bytes

# %%
data.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
data.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
data.plot(x='Hours',y='Scores',style="g.")
plt.title("INITIAL CHART")
plt.xlabel("HOURS STUDIED")
plt.ylabel("PERCENTAGE")
plt.show()

# %%
#data preparation
x=data[['Hours']].values
y=data[['Scores']].values

# %%
#importing the required function and splitting the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#training phase
from sklearn.linear_model import LinearRegression
lin=LinearRegression()
lin.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#coefficient and intercept of the model
inter=lin.intercept_
coeff=lin.coef_
print("The intercept is: ",inter)
print("the cooefficient is:",coeff[0])
# Out:
# The intercept is:  [2.82689235]
# the cooefficient is: [9.68207815]

# %%
#prediction making
y_pred=lin.predict(x_test)

# %%
#trained data
plt.scatter(x_train,y_train,label="Score")
plt.plot(x_train,lin.predict(x_train),color='red',label='line of best fit')
plt.xlabel("HOURS STUDY")
plt.ylabel("PERCENTAGE")
plt.title("BEST FIT LINE ON TRAINING DATA")
plt.legend()
plt.show()

# %%
#testing data
plt.scatter(x_test,y_test,label="Score")
plt.plot(x_test,lin.predict(x_test),color='red',label='Line of best fit')
plt.xlabel("HOURS STUDY")
plt.ylabel("PERCENTAGE")
plt.title("BEST FIT LINE ON TESTING DATA")
plt.legend()
plt.show()

# %%
#making required prediction
print("No.of.Hours=",9.25)
print("Predicted Score in %=",lin.predict([[9.25]])[0][0])
# Out:
# No.of.Hours= 9.25
# Predicted Score in %= 92.38611528261494

# %%
#evaluating the model
from sklearn import metrics
print("Mean Absolute Error :",metrics.mean_absolute_error(y_test,y_pred))
print("Mean Squared Error :",metrics.mean_squared_error(y_test,y_pred))
print("Root mean Squared Error :",np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# Mean Absolute Error : 3.9207511902099244
# Mean Squared Error : 18.943211722315272
# Root mean Squared Error : 4.352380006653288
